# %%
import cv2

cap = cv2.VideoCapture('/home/karen/Documents/ML-Models/Machine Vision/Megamind.avi')

while(True):
    ret, frame = cap.read()
    
#     if not ret:
#         # Break the loop if there are no more frames to read
#         break
    
    cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame', gray)
    
    if cv2.waitKey(1) & 0XFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
#
# QObject::moveToThread: Current thread (0x2deef70) is not the object's thread (0x33a8450).
# Cannot move to target thread (0x2deef70)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 14
#       8 #     if not ret:
#       9 #         # Break the loop if there are no more frames to read
#      10 #         break
#      12     cv2.namedWindow('frame', cv2.WINDOW_NORMAL)
# ---> 14     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#      15     cv2.imshow('frame', gray)
#      17     if cv2.waitKey(1) & 0XFF == ord('q'):
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
